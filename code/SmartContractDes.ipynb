# %% [raw]
# RQ2 测试覆盖率

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

result=pd.read_csv("result_sol_test.csv")

####函数的覆盖率
function_coverage=result['function_coverage']
#####合约的覆盖率
contract_coverage=result['contract_coverage']

all_data=[contract_coverage,function_coverage]

#首先有图（fig），然后有轴（ax）
fig,axes=plt.subplots(figsize=(8,8))

label="contract_coverage","function_coverage"
#bplot1=axes[0].boxplot(all_data,
#                       labels=label,
#                       vert=True,
#                       patch_artist=True)


bplot2 = axes.boxplot(all_data,
                         labels=label,
                         notch=True,
                         vert=True, 
                         showmeans=True,
                         patch_artist=True)



#颜色填充
colors = ['red', 'green']



        
plt.show()
fig.savefig('result/rq2-contract-function.png',bbox_inches = 'tight')
